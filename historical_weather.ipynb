# %%
#needed to make web requests
import requests

# %%
#store the data we get as a dataframe
import pandas as pd

# %%
#convert the response as a strcuctured json
import json

# %%
#mathematical operations on lists
import numpy as np

# %%
#parse the datetimes we get from NOAA
from datetime import datetime

# %%
#add the access token you got from NOAA
Token = 'XWwixSPbTBhIUdRuoIbGcgXoWOdTLHEV'

# %%
#Long Beach Airport station
station_id = 'GHCND:USW00023129'

# %%
# File to Load (Remember to Change These)
weather_data_to_load = "Resources/historical_weather.csv"

# Read Weather Data File and store into Pandas DataFrames
weather_data = pd.read_csv(weather_data_to_load)

weather_data["NAME"].unique()
# Out:
# array(['SEATTLE TACOMA AIRPORT, WA US',
#        'FORT LAUDERDALE INTERNATIONAL AIRPORT, FL US',
#        'LONG BEACH DAUGHERTY AIRPORT, CA US',
#        'MCCARRAN INTERNATIONAL AIRPORT, NV US',
#        'LAGUARDIA AIRPORT, NY US',
#        'NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US',
#        'ORLANDO SANFORD AIRPORT, FL US', 'DAL FTW WSCMO AIRPORT, TX US',
#        'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#        'WASHINGTON REAGAN NATIONAL AIRPORT, VA US',
#        'DALLAS FAA AIRPORT, TX US',
#        'LOS ANGELES INTERNATIONAL AIRPORT, CA US',
#        'EVERETT SNOHOMISH CO AIRPORT, WA US',
#        'SANTA ANA JOHN WAYNE AIRPORT, CA US',
#        'MIAMI INTERNATIONAL AIRPORT, FL US',
#        'ORLANDO INTERNATIONAL AIRPORT, FL US', 'BOSTON, MA US',
#        'SAN FRANCISCO INTERNATIONAL AIRPORT, CA US',
#        'CHICAGO MIDWAY AIRPORT, IL US',
#        'ONTARIO INTERNATIONAL AIRPORT, CA US',
#        'WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US',
# ...

# %%
weather_data.head()
# Out:
#        STATION                           NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USW00024233  SEATTLE TACOMA AIRPORT, WA US  47.44467 -122.31442      112.5
# 1  USW00024233  SEATTLE TACOMA AIRPORT, WA US  47.44467 -122.31442      112.5
# 2  USW00024233  SEATTLE TACOMA AIRPORT, WA US  47.44467 -122.31442      112.5
# 3  USW00024233  SEATTLE TACOMA AIRPORT, WA US  47.44467 -122.31442      112.5
# 4  USW00024233  SEATTLE TACOMA AIRPORT, WA US  47.44467 -122.31442      112.5
#
#          DATE  AWND  PRCP  SNOW  TAVG  TMAX  TMIN  WSF5
# 0  2011-01-01  5.37  0.00   0.0   NaN  40.0  26.0  17.0
# 1  2011-01-02  6.26  0.00   0.0   NaN  39.0  25.0  17.9
# 2  2011-01-03  5.59  0.00   0.0   NaN  42.0  27.0  15.0
# 3  2011-01-04  3.80  0.03   0.0   NaN  38.0  28.0  23.9
# 4  2011-01-05  4.92  0.12   0.0   NaN  45.0  35.0  15.0

# %%
airport_station_summary = weather_data.groupby(["NAME","STATION"]).sum()
city_summary.head()
# Out:
#                                                     STATION  LATITUDE  \
# NAME
# ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPOR...        1         1
# BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US         1         1
# BOSTON, MA US                                             1         1
# CHICAGO MIDWAY AIRPORT, IL US                             1         1
# CHICAGO OHARE INTERNATIONAL AIRPORT, IL US                1         1
#
#                                                     LONGITUDE  ELEVATION  \
# NAME
# ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPOR...          1          1
# BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US           1          1
# BOSTON, MA US                                               1          1
# CHICAGO MIDWAY AIRPORT, IL US                               1          1
# CHICAGO OHARE INTERNATIONAL AIRPORT, IL US                  1          1
#
#                                                     DATE  AWND  PRCP  SNOW  \
# NAME
# ...

# %%
airport_station_summary = weather_data.groupby(["NAME","STATION"]).mean()
city_summary.head()
# Out:
#                                                     STATION  LATITUDE  \
# NAME
# ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPOR...        1         1
# BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US         1         1
# BOSTON, MA US                                             1         1
# CHICAGO MIDWAY AIRPORT, IL US                             1         1
# CHICAGO OHARE INTERNATIONAL AIRPORT, IL US                1         1
#
#                                                     LONGITUDE  ELEVATION  \
# NAME
# ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPOR...          1          1
# BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US           1          1
# BOSTON, MA US                                               1          1
# CHICAGO MIDWAY AIRPORT, IL US                               1          1
# CHICAGO OHARE INTERNATIONAL AIRPORT, IL US                  1          1
#
#                                                     DATE  AWND  PRCP  SNOW  \
# NAME
# ...

# %%
yearly_summary = weather_data.groupby(["NAME", "LATITUDE", "LONGITUDE", "ELEVATION"]).mean()
yearly_summary.head()
# Out:
#                                                                                       AWND  \
# NAME                                               LATITUDE LONGITUDE ELEVATION
# ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPOR... 33.62972 -84.44224 308.2       7.821977
# BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US  39.17329 -76.68408 42.0        6.382091
# BOSTON, MA US                                      42.36057 -71.00975 3.2        10.821213
# CHICAGO MIDWAY AIRPORT, IL US                      41.78412 -87.75514 185.8       9.847480
# CHICAGO OHARE INTERNATIONAL AIRPORT, IL US         41.96017 -87.93164 204.8       9.691535
#
#                                                                                      PRCP  \
# NAME                                               LATITUDE LONGITUDE ELEVATION
# ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPOR... 33.62972 -84.44224 308.2      0.145648
# ...

# %%
yearly_summary = weather_data.groupby(["DATE", "NAME", "LATITUDE", "LONGITUDE", "ELEVATION"]).mean()
yearly_summary.head()
# Out:
#                                                                                              AWND  \
# DATE       NAME                                               LATITUDE LONGITUDE ELEVATION
# 2011-01-01 ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPOR... 33.62972 -84.44224 308.2       8.95
#            BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US  39.17329 -76.68408 42.0        3.80
#            BOSTON, MA US                                      42.36057 -71.00975 3.2         6.04
#            CHICAGO MIDWAY AIRPORT, IL US                      41.78412 -87.75514 185.8      18.79
#            CHICAGO OHARE INTERNATIONAL AIRPORT, IL US         41.96017 -87.93164 204.8      18.57
#
#                                                                                             PRCP  \
# DATE       NAME                                               LATITUDE LONGITUDE ELEVATION
# 2011-01-01 ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPOR... 33.62972 -84.44224 308.2      0.93
# ...

# %%
yearly_summary
# Out:
#                                                                                               AWND  \
# DATE       NAME                                               LATITUDE LONGITUDE  ELEVATION
# 2011-01-01 ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPOR... 33.62972 -84.44224  308.2       8.95
#            BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US  39.17329 -76.68408  42.0        3.80
#            BOSTON, MA US                                      42.36057 -71.00975  3.2         6.04
#            CHICAGO MIDWAY AIRPORT, IL US                      41.78412 -87.75514  185.8      18.79
#            CHICAGO OHARE INTERNATIONAL AIRPORT, IL US         41.96017 -87.93164  204.8      18.57
# ...                                                                                            ...
# 2022-07-16 PROVIDENCE, RI US                                  41.72252 -71.43248  15.4         NaN
# ...

# %%
daily_summaries = yearly_summary.copy()
daily_summaries.head(25)
# Out:
#                                                                                               AWND  \
# DATE       NAME                                               LATITUDE LONGITUDE  ELEVATION
# 2011-01-01 ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPOR... 33.62972 -84.44224  308.2       8.95
#            BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US  39.17329 -76.68408  42.0        3.80
#            BOSTON, MA US                                      42.36057 -71.00975  3.2         6.04
#            CHICAGO MIDWAY AIRPORT, IL US                      41.78412 -87.75514  185.8      18.79
#            CHICAGO OHARE INTERNATIONAL AIRPORT, IL US         41.96017 -87.93164  204.8      18.57
#            DAL FTW WSCMO AIRPORT, TX US                       32.89744 -97.02196  165.7       9.62
#            DALLAS FAA AIRPORT, TX US                          32.83839 -96.83583  147.6       8.05
# ...

# %%
daily_summaries.rename(columns={"AWND":"Average Wind Speed (mph)", "WSF5":"Max Gust (mph)",
                                "PRCP":"Precipitation (inches)", "SNOW": "Snow Accumulation (inches)",
                                "TAVG":"Average Temperature (deg F)", "TMAX":"Max Temperature (deg F)",
                                "TMIN":"Min Temperature (deg F)"}, inplace=True)
daily_summaries.head()
# Out:
#                                                                                             Average Wind Speed (mph)  \
# DATE       NAME                                               LATITUDE LONGITUDE ELEVATION
# 2011-01-01 ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPOR... 33.62972 -84.44224 308.2                          8.95
#            BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US  39.17329 -76.68408 42.0                           3.80
#            BOSTON, MA US                                      42.36057 -71.00975 3.2                            6.04
#            CHICAGO MIDWAY AIRPORT, IL US                      41.78412 -87.75514 185.8                         18.79
#            CHICAGO OHARE INTERNATIONAL AIRPORT, IL US         41.96017 -87.93164 204.8                         18.57
#
#                                                                                             Precipitation (inches)  \
# ...

# %%
daily_summaries = daily_summaries[["Average Wind Speed (mph)", "Max Gust (mph)", "Precipitation (inches)",
                                   "Snow Accumulation (inches)", "Average Temperature (deg F)",
                                  "Max Temperature (deg F)", "Min Temperature (deg F)"]]
daily_summaries
# Out:
#                                                                                              Average Wind Speed (mph)  \
# DATE       NAME                                               LATITUDE LONGITUDE  ELEVATION
# 2011-01-01 ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPOR... 33.62972 -84.44224  308.2                          8.95
#            BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US  39.17329 -76.68408  42.0                           3.80
#            BOSTON, MA US                                      42.36057 -71.00975  3.2                            6.04
#            CHICAGO MIDWAY AIRPORT, IL US                      41.78412 -87.75514  185.8                         18.79
#            CHICAGO OHARE INTERNATIONAL AIRPORT, IL US         41.96017 -87.93164  204.8                         18.57
# ...                                                                                                               ...
# ...
