# %%
#Clean airport travel data

#import dependencies
import pandas as pd

# %%
#cleaning objectives
#remove unnecessary data thats outside out date range. (jan 1st 2011 - dec 31st 2021)
#remove "total" row from dfs
#add a city column
#consolidate airport data to one df per city
#change data type for Month and TOTAL to int-64

#manipulation objectives
#consolidate all monthly data for each city into one df 
#consolidate all annual data for each city into one df

# %%
#load in travel data
boston_csv = "csv_files/boston.csv"
chi_midway_csv = "csv_files/Chicago Midway.csv"
chi_ohare_csv = "csv_files/Chicago O'Hare.csv"
las_vegas_csv = "csv_files/Las Vegas.csv"
la_csv = "csv_files/LAX new.csv"
miami_csv = "csv_files/Miami.csv"
ny_jfk_csv = "csv_files/NY JFK.csv"
ny_guardia_csv= "csv_files/NY La Guardia.csv"
orlando_csv = "csv_files/Orlando.csv"
san_fran_csv = "csv_files/San Francisco.csv"
seattle_csv = "csv_files/Seattle.csv"
dc_dulles_csv = "csv_files/Washington DC Dulles.csv"
dc_ronald_csv = "csv_files/Washington DC Ronald Reagen.csv"

# %%
#Boston
#create df for each city
b = pd.read_csv(boston_csv)

boston_df = b.loc[(b["Year"] > 2010) & (b["Year"] < 2022), :]

boston_df["City"] = "Boston"

#Remove commas and change data type for total column 
boston_df['TOTAL'] = boston_df['TOTAL'].str.replace(',','')
boston_df.astype({'TOTAL': 'int64'})

boston_df.head()
# Out:
# /var/folders/6t/7ljyhyps1g50vwwrjcwyl8bw0000gp/T/ipykernel_63114/124747642.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boston_df["City"] = "Boston"
# /var/folders/6t/7ljyhyps1g50vwwrjcwyl8bw0000gp/T/ipykernel_63114/124747642.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boston_df['TOTAL'] = boston_df['TOTAL'].str.replace(',','')
#                  Airport Airport Code  Year Month    TOTAL    City
# 108  Logan International          BOS  2011     1   894888  Boston
# ...

# %%
#create df for each city
c = pd.read_csv(chi_midway_csv)

c_ohare = pd.read_csv(chi_ohare_csv)

#add city column
c["City"] = "Chicago"
c_ohare["City"] = "Chicago"

#consolidate data into one df
chicago_df = pd.merge(c_ohare, c, how="outer")

chicago_df = chicago_df.loc[(chicago_df["Year"] > 2011) & (chicago_df["Year"] < 2022), :]

#Remove commas and change data type for total column 
chicago_df['TOTAL'] = chicago_df['TOTAL'].str.replace(',','')
chicago_df.astype({'TOTAL': 'int64'})

#chicago_df.head()
# Out:
#                           Airport Airport Code  Year  Month    TOTAL     City
# 121  Chicago O'Hare International          ORD  2012      1  2225866  Chicago
# 122  Chicago O'Hare International          ORD  2012      2  2215019  Chicago
# 123  Chicago O'Hare International          ORD  2012      3  2758340  Chicago
# 124  Chicago O'Hare International          ORD  2012      4  2620293  Chicago
# 125  Chicago O'Hare International          ORD  2012      5  2831266  Chicago
# ..                            ...          ...   ...    ...      ...      ...
# 501  Chicago Midway International          MDW  2021      9   731652  Chicago
# 502  Chicago Midway International          MDW  2021     10   760476  Chicago
# 503  Chicago Midway International          MDW  2021     11   676745  Chicago
# 504  Chicago Midway International          MDW  2021     12   641918  Chicago
# 505  Chicago Midway International          MDW  2021  TOTAL  7669456  Chicago
#
# [260 rows x 6 columns]

# %%
#las vegas
#create df for each city
lv = pd.read_csv(las_vegas_csv)

vegas_df = lv.loc[(lv["Year"] > 2011) & (lv["Year"] < 2022), :]

vegas_df["City"] = "Las Vegas"

#Remove commas and change data type for total column 
vegas_df['TOTAL'] = vegas_df['TOTAL'].str.replace(',','')
vegas_df.astype({'TOTAL': 'int64'})

vegas_df.head()
# Out:
# /var/folders/6t/7ljyhyps1g50vwwrjcwyl8bw0000gp/T/ipykernel_63114/2857719491.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vegas_df["City"] = "Las Vegas"
# /var/folders/6t/7ljyhyps1g50vwwrjcwyl8bw0000gp/T/ipykernel_63114/2857719491.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vegas_df['TOTAL'] = vegas_df['TOTAL'].str.replace(',','')
#                     Airport Airport Code  Year Month    TOTAL       City
# ...

# %%
#miami
#create df for each city
m = pd.read_csv(miami_csv)

miami_df = m.loc[(m["Year"] > 2011) & (m["Year"] < 2022), :]

miami_df["City"] = "Miami"

#Remove commas and change data type for total column 
miami_df['TOTAL'] = miami_df['TOTAL'].str.replace(',','')
miami_df.astype({'TOTAL': 'int64'})

miami_df.head()
# Out:
# /var/folders/6t/7ljyhyps1g50vwwrjcwyl8bw0000gp/T/ipykernel_63114/954561235.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   miami_df["City"] = "Miami"
# /var/folders/6t/7ljyhyps1g50vwwrjcwyl8bw0000gp/T/ipykernel_63114/954561235.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   miami_df['TOTAL'] = miami_df['TOTAL'].str.replace(',','')
#                  Airport Airport Code  Year Month    TOTAL   City
# 121  Miami International          MIA  2012     1  1682719  Miami
# ...

# %%
#LA
#create df for each city
la = pd.read_csv(la_csv)

los_angeles_df = la.loc[(la["Year"] > 2011) & (la["Year"] < 2022), :]

los_angeles_df["City"] = "Los Angeles"

#Remove commas and change data type for total column 
los_angeles_df['TOTAL'] = los_angeles_df['TOTAL'].str.replace(',','')
los_angeles_df.astype({'TOTAL': 'int64'})

los_angeles_df.head()
# Out:
# /var/folders/6t/7ljyhyps1g50vwwrjcwyl8bw0000gp/T/ipykernel_63114/2573051315.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   los_angeles_df["City"] = "Los Angeles"
# /var/folders/6t/7ljyhyps1g50vwwrjcwyl8bw0000gp/T/ipykernel_63114/2573051315.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   los_angeles_df['TOTAL'] = los_angeles_df['TOTAL'].str.replace(',','')
#                        Airport Airport Code  Year Month      TOTAL  \
# ...

# %%
#new york 
#create df for each city
ny = pd.read_csv(ny_guardia_csv)

ny_jfk = pd.read_csv(ny_jfk_csv)

#add city column
ny["City"] = "New York"
ny_jfk["City"] = "New York"

#consolidate data into one df
ny_df = pd.merge(ny, ny_jfk, how="outer")

ny_df = ny_df.loc[(ny_df["Year"] > 2011) & (ny_df["Year"] < 2022), :]

#Remove commas and change data type for total column 
ny_df['TOTAL'] = ny_df['TOTAL'].str.replace(',','')
ny_df.astype({'TOTAL': 'int64'})

ny_df.head()
# Out:
#        Airport Airport Code  Year Month    TOTAL      City
# 121  LaGuardia          LGA  2012     1   850513  New York
# 122  LaGuardia          LGA  2012     2   833720  New York
# 123  LaGuardia          LGA  2012     3  1013248  New York
# 124  LaGuardia          LGA  2012     4  1085393  New York
# 125  LaGuardia          LGA  2012     5  1118440  New York

# %%
#Orlando
#create df for each city
o = pd.read_csv(orlando_csv)

orlando_df = o.loc[(o["Year"] > 2011) & (o["Year"] < 2022), :]

orlando_df["City"] = "Orlando"

#Remove commas and change data type for total column 
orlando_df['TOTAL'] = orlando_df['TOTAL'].str.replace(',','')
orlando_df.astype({'TOTAL': 'int64'})

orlando_df.head()
# Out:
# /var/folders/6t/7ljyhyps1g50vwwrjcwyl8bw0000gp/T/ipykernel_63114/2128521377.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orlando_df["City"] = "Orlando"
# /var/folders/6t/7ljyhyps1g50vwwrjcwyl8bw0000gp/T/ipykernel_63114/2128521377.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orlando_df['TOTAL'] = orlando_df['TOTAL'].str.replace(',','')
#                    Airport Airport Code  Year Month    TOTAL     City
# ...

# %%
#San Fransico
#create df for each city
sf = pd.read_csv(san_fran_csv)

san_fran_df = sf.loc[(sf["Year"] > 2011) & (sf["Year"] < 2022), :]

san_fran_df["City"] = "San Francisco"

#Remove commas and change data type for total column 
san_fran_df['TOTAL'] = vegas_df['TOTAL'].str.replace(',','')
san_fran_df.astype({'TOTAL': 'int64'})

san_fran_df.head()
# Out:
# /var/folders/6t/7ljyhyps1g50vwwrjcwyl8bw0000gp/T/ipykernel_63114/71038935.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   san_fran_df["City"] = "San Francisco"
# /var/folders/6t/7ljyhyps1g50vwwrjcwyl8bw0000gp/T/ipykernel_63114/71038935.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   san_fran_df['TOTAL'] = vegas_df['TOTAL'].str.replace(',','')
#                          Airport Airport Code  Year Month    TOTAL  \
# ...

# %%
#seattle
#create df for each city
s = pd.read_csv(seattle_csv)

seattle_df = s.loc[(s["Year"] > 2011) & (s["Year"] < 2022), :]

seattle_df["City"] = "Seattle"

#Remove commas and change data type for total column 
seattle_df['TOTAL'] = seattle_df['TOTAL'].str.replace(',','')
seattle_df.astype({'TOTAL': 'int64'})

seattle_df.head()
# Out:
# /var/folders/6t/7ljyhyps1g50vwwrjcwyl8bw0000gp/T/ipykernel_63114/1375555143.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seattle_df["City"] = "Seattle"
# /var/folders/6t/7ljyhyps1g50vwwrjcwyl8bw0000gp/T/ipykernel_63114/1375555143.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seattle_df['TOTAL'] = seattle_df['TOTAL'].str.replace(',','')
#                           Airport Airport Code  Year Month    TOTAL     City
# ...

# %%
#Washington DC
#create df for each city
dc = pd.read_csv(dc_dulles_csv)

dc_ronald = pd.read_csv(dc_ronald_csv)

#add city column
dc["City"] = "Washington DC"
dc_ronald["City"] = "Washington DC"

#consolidate data into one df
dc_df = pd.merge(dc, dc_ronald, how="outer")

dc_df = dc_df.loc[(dc_df["Year"] > 2011) & (dc_df["Year"] < 2022), :]

#Remove commas and change data type for total column 
dc_df['TOTAL'] = dc_df['TOTAL'].str.replace(',','')
dc_df.astype({'TOTAL': 'int64'})

dc_df.head()
# Out:
#                              Airport Airport Code  Year Month   TOTAL  \
# 121  Washington Dulles International          IAD  2012     1  785579
# 122  Washington Dulles International          IAD  2012     2  724980
# 123  Washington Dulles International          IAD  2012     3  916911
# 124  Washington Dulles International          IAD  2012     4  918012
# 125  Washington Dulles International          IAD  2012     5  990182
#
#               City
# 121  Washington DC
# 122  Washington DC
# 123  Washington DC
# 124  Washington DC
# 125  Washington DC

# %%
city_list = [chicago_df, los_angeles_df, vegas_df, ny_df, orlando_df, san_fran_df, seattle_df, dc_df]
total_arrivals = boston_df.loc[(boston_df["Month"] == "TOTAL"), :]
monthly_arrivals = boston_df[boston_df["Month"] != "TOTAL"]

#Create a Dataframe for annual results for all 10 cities
for city in city_list:
    temp_city = city.loc[(city["Month"] == "TOTAL"), :]
    total_arrivals = pd.merge(total_arrivals, temp_city, how="outer")

#Create a Dataframe for monthly results for all 10 cities
for place in city_list:
    temp_place = place[place["Month"] != "TOTAL"]
    monthly_arrivals = pd.merge(monthly_arrivals, temp_place, how="outer")

#change data type of month to integer now that the "TOTAL" value has been removed
monthly_arrivals = monthly_arrivals.astype({'Month': 'int64'})
monthly_arrivals = monthly_arrivals.astype({'TOTAL': 'int64'})

total_arrivals = total_arrivals.astype({'TOTAL': 'int64'})

# %%
total_arrivals.reset_index(inplace=True)
total_arrivals = total_arrivals.rename(columns = {'index':'id'})

# %%
total_arrivals.head()
#len(total_arrivals)
#total_arrivals["Airport"].unique()
#total_arrivals["City"].unique()
# Out:
#    id              Airport Airport Code  Year  Month     TOTAL    City
# 0   0  Logan International          BOS  2011  TOTAL  14146849  Boston
# 1   1  Logan International          BOS  2012  TOTAL  14271609  Boston
# 2   2  Logan International          BOS  2013  TOTAL  14787085  Boston
# 3   3  Logan International          BOS  2014  TOTAL  15480701  Boston
# 4   4  Logan International          BOS  2015  TOTAL  16311924  Boston

# %%
total_arrivals.groupby(total_arrivals["City"]).mean()["TOTAL"]
# Out:
# City
# Boston           1.536839e+07
# Chicago          2.135026e+07
# Las Vegas        2.048615e+07
# Los Angeles      3.385630e+07
# New York         1.866957e+07
# Orlando          1.895278e+07
# San Francisco    2.048615e+07
# Seattle          1.909013e+07
# Washington DC    9.752278e+06
# Name: TOTAL, dtype: float64

# %%
monthly_arrivals.reset_index(inplace=True)
monthly_arrivals = monthly_arrivals.rename(columns = {'index':'id'})

# %%
monthly_arrivals.head()
#len(monthly_arrivals)
#monthly_arrivals["Airport"].unique()
#monthly_arrivals["Month"].value_counts()
# Out:
#    id              Airport Airport Code  Year  Month    TOTAL    City
# 0   0  Logan International          BOS  2011      1   894888  Boston
# 1   1  Logan International          BOS  2011      2   905854  Boston
# 2   2  Logan International          BOS  2011      3  1144991  Boston
# 3   3  Logan International          BOS  2011      4  1201842  Boston
# 4   4  Logan International          BOS  2011      5  1267878  Boston

# %%
monthly_arrivals.groupby(monthly_arrivals["City"]).mean()["TOTAL"]
# Out:
# City
# Boston           1.280699e+06
# Chicago          1.779188e+06
# Las Vegas        1.707179e+06
# Los Angeles      2.821359e+06
# New York         1.555798e+06
# Orlando          1.579398e+06
# San Francisco    1.707179e+06
# Seattle          1.590844e+06
# Washington DC    8.126899e+05
# Name: TOTAL, dtype: float64

# %%
# File to Load (Remember to Change These)
weather_data_to_load = "csv_files/monthly_summary.csv"

# Read Weather Data File and store into Pandas DataFrames
weather_data = pd.read_csv(weather_data_to_load)

# %%
weather_data
# Out:
#           STATION                                        NAME  LATITUDE  \
# 0     USW00024233               SEATTLE TACOMA AIRPORT, WA US  47.44467
# 1     USW00024233               SEATTLE TACOMA AIRPORT, WA US  47.44467
# 2     USW00024233               SEATTLE TACOMA AIRPORT, WA US  47.44467
# 3     USW00024233               SEATTLE TACOMA AIRPORT, WA US  47.44467
# 4     USW00024233               SEATTLE TACOMA AIRPORT, WA US  47.44467
# ...           ...                                         ...       ...
# 3463  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  41.96017
# 3464  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  41.96017
# 3465  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  41.96017
# 3466  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  41.96017
# 3467  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  41.96017
#
#       LONGITUDE  ELEVATION     DATE  AWND  PRCP  SNOW  TAVG  TMAX  TMIN  \
# ...

# %%
weather_data = weather_data[["NAME", "LATITUDE", "LONGITUDE", "ELEVATION", "DATE", "AWND", "WSF5", "PRCP", "SNOW",
                            "TAVG", "TMAX", "TMIN"]]

weather_data["AIRPORT"] = weather_data["NAME"].str.split(",").str[0]


weather_data.head()
# Out:
# /var/folders/6t/7ljyhyps1g50vwwrjcwyl8bw0000gp/T/ipykernel_63114/1806008989.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weather_data["AIRPORT"] = weather_data["NAME"].str.split(",").str[0]
#                             NAME  LATITUDE  LONGITUDE  ELEVATION     DATE  \
# 0  SEATTLE TACOMA AIRPORT, WA US  47.44467 -122.31442      112.5  2011-01
# 1  SEATTLE TACOMA AIRPORT, WA US  47.44467 -122.31442      112.5  2011-02
# 2  SEATTLE TACOMA AIRPORT, WA US  47.44467 -122.31442      112.5  2011-03
# 3  SEATTLE TACOMA AIRPORT, WA US  47.44467 -122.31442      112.5  2011-04
# 4  SEATTLE TACOMA AIRPORT, WA US  47.44467 -122.31442      112.5  2011-05
#
#    AWND  WSF5  PRCP  SNOW  TAVG  TMAX  TMIN                 AIRPORT
# ...

# %%
weather_data["NAME"].replace({"SEATTLE TACOMA AIRPORT, WA US":"SEA",
                              "FORT LAUDERDALE INTERNATIONAL AIRPORT, FL US": "FLL",
                              "LONG BEACH DAUGHERTY AIRPORT, CA US":"LGB",
                              "MCCARRAN INTERNATIONAL AIRPORT, NV US":"LAS",
                              "LAGUARDIA AIRPORT, NY US":"LGA",
                              "NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US":"EWR",
                              "ORLANDO SANFORD AIRPORT, FL US":"SFB",
                              "DAL FTW WSCMO AIRPORT, TX US":"DFW",
                              "BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US":"BWI",
                              "WASHINGTON REAGAN NATIONAL AIRPORT, VA US":"DCA",
                              "DALLAS FAA AIRPORT, TX US":"DAL",
                              "LOS ANGELES INTERNATIONAL AIRPORT, CA US":"LAX",
                              "EVERETT SNOHOMISH CO AIRPORT, WA US":"PAE",
                              "SANTA ANA JOHN WAYNE AIRPORT, CA US":"SNA",
                              "MIAMI INTERNATIONAL AIRPORT, FL US":"MIA",
                              "ORLANDO INTERNATIONAL AIRPORT, FL US":"MCO",
                              "BOSTON, MA US":"BOS",
                              "SAN FRANCISCO INTERNATIONAL AIRPORT, CA US":"SFO",
                              "CHICAGO MIDWAY AIRPORT, IL US":"ORD",
                              "ONTARIO INTERNATIONAL AIRPORT, CA US":"ONT",
                              "WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US":"IAD",
                              "PROVIDENCE, RI US":"PVD",
                              "JFK INTERNATIONAL AIRPORT, NY US":"JFK",
                              "ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US":"ATL",
                              "CHICAGO OHARE INTERNATIONAL AIRPORT, IL US":"ORD"
                             }, inplace = True)
weather_data.head()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
#   NAME  LATITUDE  LONGITUDE  ELEVATION     DATE  AWND  WSF5  PRCP  SNOW  TAVG  \
# 0  SEA  47.44467 -122.31442      112.5  2011-01   7.8  40.0  4.99   2.8  41.8
# 1  SEA  47.44467 -122.31442      112.5  2011-02   8.7  46.0  3.06   2.0  39.3
# 2  SEA  47.44467 -122.31442      112.5  2011-03   9.8  55.0  6.29   0.0  45.2
# 3  SEA  47.44467 -122.31442      112.5  2011-04   8.5  36.0  4.47   0.0  45.5
# 4  SEA  47.44467 -122.31442      112.5  2011-05   7.2  32.0  3.20   0.0  52.3
#
#    TMAX  TMIN                 AIRPORT
# 0  46.2  37.3  SEATTLE TACOMA AIRPORT
# 1  45.0  33.5  SEATTLE TACOMA AIRPORT
# 2  51.4  38.9  SEATTLE TACOMA AIRPORT
# ...

# %%
weather_data.rename(columns={"NAME": "AIRPORT CODE"}, inplace=True)
weather_data.head()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#   AIRPORT CODE  LATITUDE  LONGITUDE  ELEVATION     DATE  AWND  WSF5  PRCP  \
# 0          SEA  47.44467 -122.31442      112.5  2011-01   7.8  40.0  4.99
# 1          SEA  47.44467 -122.31442      112.5  2011-02   8.7  46.0  3.06
# 2          SEA  47.44467 -122.31442      112.5  2011-03   9.8  55.0  6.29
# 3          SEA  47.44467 -122.31442      112.5  2011-04   8.5  36.0  4.47
# 4          SEA  47.44467 -122.31442      112.5  2011-05   7.2  32.0  3.20
#
#    SNOW  TAVG  TMAX  TMIN                 AIRPORT
# 0   2.8  41.8  46.2  37.3  SEATTLE TACOMA AIRPORT
# 1   2.0  39.3  45.0  33.5  SEATTLE TACOMA AIRPORT
# ...

# %%
weather_data = weather_data[["AIRPORT CODE", "AIRPORT", "LATITUDE", "LONGITUDE", "ELEVATION", "DATE",
                            "AWND", "WSF5", "PRCP", "SNOW", "TAVG", "TMAX", "TMIN"]]

# %%
weather_data
# Out:
#      AIRPORT CODE                              AIRPORT  LATITUDE  LONGITUDE  \
# 0             SEA               SEATTLE TACOMA AIRPORT  47.44467 -122.31442
# 1             SEA               SEATTLE TACOMA AIRPORT  47.44467 -122.31442
# 2             SEA               SEATTLE TACOMA AIRPORT  47.44467 -122.31442
# 3             SEA               SEATTLE TACOMA AIRPORT  47.44467 -122.31442
# 4             SEA               SEATTLE TACOMA AIRPORT  47.44467 -122.31442
# ...           ...                                  ...       ...        ...
# 3463          ORD  CHICAGO OHARE INTERNATIONAL AIRPORT  41.96017  -87.93164
# 3464          ORD  CHICAGO OHARE INTERNATIONAL AIRPORT  41.96017  -87.93164
# 3465          ORD  CHICAGO OHARE INTERNATIONAL AIRPORT  41.96017  -87.93164
# 3466          ORD  CHICAGO OHARE INTERNATIONAL AIRPORT  41.96017  -87.93164
# 3467          ORD  CHICAGO OHARE INTERNATIONAL AIRPORT  41.96017  -87.93164
#
# ...

# %%
weather_data.rename(columns={"AWND":"Average Wind Speed", "WSF5":"Max Gust Speed",
                                "PRCP":"Precipitation", "SNOW": "Snow Accumulation",
                                "TAVG":"Average Temperature", "TMAX":"Max Temperature",
                                 "TMIN":"Min Temperature"}, inplace=True)

# %%
monthly_summary = weather_data.groupby(["DATE", "AIRPORT CODE", "AIRPORT", "LATITUDE", "LONGITUDE", "ELEVATION"]).mean()

# %%
monthly_summary.reset_index(inplace=True)
monthly_summary.reset_index(inplace=True)
monthly_summary = monthly_summary.rename(columns = {'index':'id'})

# %%
monthly_summary
# Out:
#         id     DATE AIRPORT CODE  \
# 0        0  2011-01          ATL
# 1        1  2011-01          BOS
# 2        2  2011-01          BWI
# 3        3  2011-01          DAL
# 4        4  2011-01          DCA
# ...    ...      ...          ...
# 3463  3463  2022-07          PAE
# 3464  3464  2022-07          PVD
# 3465  3465  2022-07          SEA
# 3466  3466  2022-07          SFB
# 3467  3467  2022-07          SFO
#
#                                                AIRPORT  LATITUDE  LONGITUDE  \
# 0     ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT  33.62972  -84.44224
# 1                                               BOSTON  42.36057  -71.00975
# 2           BALTIMORE WASHINGTON INTERNATIONAL AIRPORT  39.17329  -76.68408
# 3                                   DALLAS FAA AIRPORT  32.83839  -96.83583
# 4                   WASHINGTON REAGAN NATIONAL AIRPORT  38.84721  -77.03454
# ...                                                ...       ...        ...
# ...

# %% [markdown]
# Create Database in PgAdmin4

# %%
import psycopg2
from sqlalchemy import create_engine, func
import config

# %%
# Connect to your Postgres database
engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(config.username, config.password, 'localhost', 5432, 'city_weather_db'))
con = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/6t/7ljyhyps1g50vwwrjcwyl8bw0000gp/T/ipykernel_63114/3193180295.py in <module>
#       1 # Connect to your Postgres database
# ----> 2 engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(config.username, config.password, 'localhost', 5432, 'city_weather_db'))
#       3 con = engine.connect()
#
# AttributeError: module 'config' has no attribute 'username'

# %%
# use pandas to load monthly_arrivals dataframe into the database
monthly_arrivals.to_sql('monthly_arrivals', con, if_exists='replace', index=False)


# use pandas to load total_arrivals dataframe into the database
total_arrivals.to_sql('total_arrivals', con, if_exists='replace', index=False)

# %%
# use pandas to load  monthly weather dataframe into the database
monthly_summary.to_sql('monthly_summary', con, if_exists='replace', index=False)

# %%
pd.read_sql_query('select * from monthly_summary', con=engine).head()

# %%
# confirm that the data was loaded into the fit_weather_data table
pd.read_sql_query('select * from total_arrivals', con=engine).head()

# %%
# confirm that the data was loaded into the fit_weather_data table
pd.read_sql_query('select * from total_arrivals', con=engine).head()
